# %%
import pandas as pd
import sys
import numpy as np

# %%
df = pd.read_csv("/Volumes/T7/Python_Projects/Document Segmentation using NER & Visual Features (Dataset creation)/data/Unseen/unseen_test_set_2001.csv")

# %%
df.head()
# Out:
#                   Scan File_Name     archive_code  inventory_id  page_num  \
# 0  NL-HaNA_1.04.02_2001_0001.xml  NL_HaNA_1.04.02          2001         1
# 1  NL-HaNA_1.04.02_2001_0002.xml  NL_HaNA_1.04.02          2001         2
# 2  NL-HaNA_1.04.02_2001_0003.xml  NL_HaNA_1.04.02          2001         3
# 3  NL-HaNA_1.04.02_2001_0004.xml  NL_HaNA_1.04.02          2001         4
# 4  NL-HaNA_1.04.02_2001_0005.xml  NL_HaNA_1.04.02          2001         5
#
#                    base_name  \
# 0  NL-HaNA_1.04.02_2001_0001
# 1  NL-HaNA_1.04.02_2001_0002
# 2  NL-HaNA_1.04.02_2001_0003
# 3  NL-HaNA_1.04.02_2001_0004
# 4  NL-HaNA_1.04.02_2001_0005
#
#                                             xml_data  \
# 0  <?xml version='1.0' encoding='UTF-8'?>\n<PcGts...
# 1  <?xml version='1.0' encoding='UTF-8'?>\n<PcGts...
# 2  <?xml version='1.0' encoding='UTF-8'?>\n<PcGts...
# 3  <?xml version='1.0' encoding='UTF-8'?>\n<PcGts...
# 4  <?xml version='1.0' encoding='UTF-8'?>\n<PcGts...
#
# ...
